# %% [markdown]
# # Introduction
# Quick validation of cmorized NorESM3 data for CMIP7

# %%
# parameters for the cmorized data
cmorout=''                  # root for cmorized data, e.g., '/scratch/$USER/cmorout'
source_id      = ''         # model name, e.g., 'NorESM3-LM'
experiment_id  = ''         # experiment name, e.g., 'historical', 'ssp585', 'piControl'
variant_label  = ''         # variant label, e.g., 'r1i1p1f1'
grid_label     = ''         # grid label, e.g., 'gn', 'gr', 'g999'
version        = ''         # version, e.g., 'v20260601'

# %% [markdown]
# Plots for different variable types:
#
# <!-- >
# list of all cmorized variable coords:
# cat variables.nml|grep 'ocean.' | cut -d"'" -f2 |cut -d. -f3 |sort -u
# tavg-d2000m-hxy-sea     ! ocean 2D
# tavg-d300m-hxy-sea      ! ocean 2D
# tavg-d700m-hxy-sea      ! ocean 2D
# tavg-ol-hm-sea          ! removed in drq v1.2.2.4
# tavg-ol-hxy-sea         ! ocean 3D
# tavg-ol-hyb-sea         ! ocean zonal
# tavg-rho-hyb-sea        ! ocean zonal
# tavg-u-hm-sea           ! ocean 1d
# tavg-u-ht-sea           ! ocean line
# tavg-u-hxy-ifs          ! ocean 2D
# tavg-u-hxy-sea          ! ocean 2D
# tavg-u-hyb-sea          :
# ti-ol-hxy-sea
# ti-u-hxy-sea            ! ocean fx
# ti-u-hxy-u              ! ocean fx
# tmax-u-hxy-sea          ! ocean 2D
# tmin-u-hxy-sea          ! ocean 2D
# <-->
# * ocean_fx: ('ti-u-hxy-sea', 'ti-u-hxy-u')
# * ocean_line: ('tavg-u-ht-sea')
# * ocean_1D: ('tavg-u-hm-sea')
# * ocean_zonal: ('tavg-u-hyb-sea')
# * ocean_2D: ('tavg-u-hxy-sea', 'tmax-u-hxy-sea', 'tmin-u-hxy-sea', 'tavg-d300m-hxy-sea', 'tavg-d700m-hxy-sea', 'tavg-d2000m-hxy-sea')
# * ocean_3D: ('tavg-ol-hxy-sea')
#
#
#
# ```{tableofcontents}
# ```
